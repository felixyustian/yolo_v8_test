# %% [markdown]
# <a href="https://colab.research.google.com/github/felixyustian/yolo_v8_test/blob/main/yolov8_custom_train.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 873.3/873.3 kB 19.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/krti2024/
# Out:
# /content/drive/MyDrive/krti2024

# %%
mkdir yolov8
# Out:
# mkdir: cannot create directory ‘yolov8’: File exists

# %%
cd yolov8
# Out:
# /content/drive/MyDrive/krti2024/yolov8

# %%
ls
# Out:
# data/      Dockerfile  __pycache__/         requirements.txt  utils/
# datasets/  hubconf.py  README.md            runs/             yolov8n.pt
# data.yaml  LICENSE     README.roboflow.txt  tutorial.ipynb    yolov8s.pt

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8s.pt")

# %%
results = model.train(data="data.yaml", epochs=100, batch=16, imgsz=320)
# Out:
# Ultralytics YOLOv8.2.96 🚀 Python-3.10.12 torch-2.4.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
cd /content/drive/MyDrive/krti2024/yolov8/runs/detect/train3/weights/
# Out:
# /content/drive/MyDrive/krti2024/yolov8/runs/detect/train3/weights

# %%
model = YOLO("best.pt")

# %%
model.export(imgsz=320, format="onnx", dynamic=True, opset=11)
# Out:
# Ultralytics YOLOv8.2.96 🚀 Python-3.10.12 torch-2.4.0+cu121 CPU (Intel Xeon 2.20GHz)
# Model summary (fused): 168 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
#
# PyTorch: starting from 'best.pt' with input shape (1, 3, 320, 320) BCHW and output shape(s) (1, 7, 2100) (21.4 MB)
#
# ONNX: starting export with onnx 1.16.2 opset 11...
# ONNX: export success ✅ 1.3s, saved as 'best.onnx' (42.5 MB)
#
# Export complete (3.0s)
# Results saved to /content/drive/MyDrive/krti2024/yolov8/runs/detect/train3/weights
# Predict:         yolo predict task=detect model=best.onnx imgsz=320
# Validate:        yolo val task=detect model=best.onnx imgsz=320 data=data.yaml
# Visualize:       https://netron.app
# 'best.onnx'

# %%
pip install hailo_dataflow_compiler-3.27.0-py3-none-linux_x86_64.whl
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-40-35a159513dd6> in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('pip', 'install hailo_dataflow_compiler-3.27.0-py3-none-linux_x86_64.whl')
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_installation_commands.py in _pip_magic(line)
#      47   # Colab is set up such that pip does the right thing, and pip install
#      48   # will properly trigger the pip install warning.
# ---> 49   return ip.system('pip {}'.format(line))
#      50
# ...
